# %% [markdown]
# Let's create dictionary for the amino acid letter to its full name.

# %%
aminoAcids = {
    "A": "Alanine",
    "C": "Cysteine",
    "D": "Aspartic",
    "E": "Glutamic",
    "F": "Phenylalanine",
    "G": "Glycine",
    "H": "Histidine",
    "I": "Isoleucine",
    "K": "Lysine",
    "L": "Leucine",
    "M": "Methionine",
    "N": "Asparagine",
    "P": "Proline",
}
